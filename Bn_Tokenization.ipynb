# %%
# !pip install sentencepiece
import sentencepiece as spm
import pickle
import pathlib

# %%
# import zipfile
# zip_ref = zipfile.ZipFile("BengaliWikipediaArticles.zip", "r")
# zip_ref.extractall()

# %%
ls
# Out:
# BengaliWikipediaArticles/  BengaliWikipediaArticles.zip  sample_data/

# %%
path = pathlib.Path('')

# %%
p = path.glob('BengaliWikipediaArticles/*')
files = [x for x in p if x.is_file()]

# %%
files
# Out:
# [PosixPath('BengaliWikipediaArticles/50027.pkl'),
#  PosixPath('BengaliWikipediaArticles/28098.pkl'),
#  PosixPath('BengaliWikipediaArticles/2785.pkl'),
#  PosixPath('BengaliWikipediaArticles/1753.pkl'),
#  PosixPath('BengaliWikipediaArticles/6692.pkl'),
#  PosixPath('BengaliWikipediaArticles/18852.pkl'),
#  PosixPath('BengaliWikipediaArticles/15436.pkl'),
#  PosixPath('BengaliWikipediaArticles/72001.pkl'),
#  PosixPath('BengaliWikipediaArticles/12174.pkl'),
#  PosixPath('BengaliWikipediaArticles/58575.pkl'),
#  PosixPath('BengaliWikipediaArticles/12398.pkl'),
#  PosixPath('BengaliWikipediaArticles/39551.pkl'),
#  PosixPath('BengaliWikipediaArticles/59461.pkl'),
#  PosixPath('BengaliWikipediaArticles/66873.pkl'),
#  PosixPath('BengaliWikipediaArticles/40004.pkl'),
#  PosixPath('BengaliWikipediaArticles/68424.pkl'),
#  PosixPath('BengaliWikipediaArticles/28286.pkl'),
#  PosixPath('BengaliWikipediaArticles/26830.pkl'),
#  PosixPath('BengaliWikipediaArticles/66400.pkl'),
# ...

# %%
len(files)
# Out:
# 72374

# %%
files = [str(file) for file in files]

# %%
flist = ','.join(files)

# %%
spm.SentencePieceTrainer.Train(f'--input={flist} --model_prefix=bengali_lm --vocab_size=30000')
# Out:
# True

# %%
with open(path/'BengaliWikipediaArticles/1781.pkl', 'rb') as f:
    text = pickle.load(f)

# %%
text
# Out:
# 'ভগৎ সিংহ  ছিলেন ভারতীয় উপমহাদেশের ব্রিটিশ বিরোধী স্বাধীনতা আন্দোলনের একজন পুরোধা ব্যক্তিত্ব ও অগ্নিযুগের শহীদ বিপ্লবী। দেশের স্বাধীনতা সংগ্রামে তিনি ছিলেন অন্যতম প্রভাবশালী বিপ্লবী। তাঁকে শহিদ-ঈ আজম ভগৎ সিংহ নামে অভিহিত করা হয়। বাংলাদেশের মাটিতে তাকে শ্রদ্ধাভরে স্মরণ করে বাসদ  সহ প্রায় সকল বামপন্থি দলসমূহ।\nভগৎ সিংহের জন্ম একটি জাট শিখ পরিবারে। তাঁর পরিবার পূর্ব থেকেই ব্রিটিশ বিরোধী বিপ্লবী আন্দোলনের সঙ্গে জড়িত ছিল। কৈশোরেই ভগৎ ইউরোপীয় বিপ্লবী আন্দোলনের ইতিহাস সম্পর্কে পড়াশোনা করেন এবং নৈরাজ্যবাদ ও কমিউনিজমের প্রতি আকৃষ্ট হন। এরপর তিনি একাধিক বিপ্লবী সংগঠনের সঙ্গে যুক্ত হয়ে পড়েন। হিন্দুস্তান রিপাবলিকান অ্যাসোসিয়েশনের সঙ্গে যুক্ত হয়ে মেধা, জ্ঞান ও নেতৃত্বদানের ক্ষমতায় তিনি অচিরেই এই সংগঠনে নেতায় পরিণত হন এবং সংগঠনটিতে ব্যাপক পরিবর্তন এনে এটিকে হিন্দুস্তান সোশ্যালিস্ট রিপাবলিকান অ্যাসোসিয়েশনে রূপান্তরিত করেন। তাকে এবং তার সংগঠনকে নৈরাজ্যবাদী আখ্যা দেওয়া হলে তিনি ক্ষুরধার যুক্তিতে তা খন্ডন করেন। জেলে ভারতীয় ও ব্রিটিশ বন্দীদের সমানাধিকারের দাবিতে ৬৪ দিন টানা অনশন চালিয়ে 
# ...

# %%
sp = spm.SentencePieceProcessor()

# %%
sp.Load("bengali_lm.model")
# Out:
# True

# %%
' '.join(sp.EncodeAsPieces(text))
# Out:
# '▁ভগৎ ▁সিংহ ▁ছিলেন ▁ভারতীয় ▁উপমহাদেশের ▁ব্রিটিশ ▁বিরোধী ▁স্বাধীনতা ▁আন্দোলনের ▁একজন ▁পুরোধা ▁ব্যক্তিত্ব ▁ও ▁অগ্নিযুগ ের ▁শহীদ ▁বিপ্লবী । ▁দেশের ▁স্বাধীনতা ▁সংগ্রামে ▁তিনি ▁ছিলেন ▁অন্যতম ▁প্রভাবশালী ▁বিপ্লবী । ▁তাঁকে ▁শহিদ - ঈ ▁আজম ▁ভগৎ ▁সিংহ ▁নামে ▁অভিহিত ▁করা ▁হয় । ▁বাংলাদেশের ▁মাটিতে ▁তাকে ▁শ্রদ্ধা ভর ে ▁স্মরণ ▁করে ▁বাস দ ▁সহ ▁প্রায় ▁সকল ▁বাম পন্থি ▁দলসমূহ । ▁ভগৎ ▁সিংহের ▁জন্ম ▁একটি ▁জা ট ▁শিখ ▁পরিবারে । ▁তাঁর ▁পরিবার ▁পূর্ব ▁থেকেই ▁ব্রিটিশ ▁বিরোধী ▁বিপ্লবী ▁আন্দোলনের ▁সঙ্গে ▁জড়িত ▁ছিল । ▁কৈশোরে ই ▁ভগৎ ▁ইউরোপীয় ▁বিপ্লবী ▁আন্দোলনের ▁ইতিহাস ▁সম্পর্কে ▁পড়াশোনা ▁করেন ▁এবং ▁নৈরাজ্য বাদ ▁ও ▁কমিউনিজম ের ▁প্রতি ▁আকৃষ্ট ▁হন । ▁এরপর ▁তিনি ▁একাধিক ▁বিপ্লবী ▁সংগঠনের ▁সঙ্গে ▁যুক্ত ▁হয়ে ▁পড়েন । ▁হিন্দুস্তান ▁রিপাবলিকান ▁অ্যাসোসিয়েশনের ▁সঙ্গে ▁যুক্ত ▁হয়ে ▁মেধা , ▁জ্ঞান ▁ও ▁নেতৃত্বদান ের ▁ক্ষমতায় ▁তিনি ▁অচিরেই ▁এই ▁সংগঠন ে ▁নেতা য় ▁পরিণত ▁হন ▁এবং ▁সংগঠনটি তে ▁ব্যাপক ▁পরিবর্তন ▁এনে ▁এটিকে ▁হিন্দুস্তান ▁সোশ্যালিস্ট ▁রিপাবলিকান ▁অ্যাসোসিয়েশন ে ▁রূপান্তরিত ▁করেন । ▁তাকে ▁এবং ▁তার ▁সংগঠন ক
# ...

# %%
text = "আমার সোনার বাংলা আমি তোমাই ভালোবাসি। চিরদিন তোমার"
x = ''.join(sp.EncodeAsPieces(text))
token = x.split("▁")
token
# Out:
# ['', 'আমার', 'সোনার', 'বাংলা', 'আমি', 'তোমাই', 'ভালোবাসি।', 'চিরদিন', 'তোমার']
